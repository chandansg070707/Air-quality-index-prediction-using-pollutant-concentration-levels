# %% [markdown]
# <a href="https://colab.research.google.com/github/chandansg070707/Air-quality-index-prediction-using-pollutant-concentration-levels/blob/main/airindex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Air quality index prediction using pollutant concentration levels**

# %% [markdown]
# NAME:chandan s g
#
# BRANCH:data science
#
# EMAIL:chandansg777gmail.com
#
# COLLEGE EMAIL:chandansg.24ds@cambridge.edu.in

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/air_quality.csv')

# %% [markdown]
# INFORMATION OF THE FILE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pm25_ugm3            952 non-null    float64
#  1   pm10_ugm3            961 non-null    float64
#  2   no2_ppb              956 non-null    float64
#  3   so2_ppb              946 non-null    float64
#  4   co_ppm               945 non-null    float64
#  5   o3_ppb               950 non-null    float64
#  6   wind_speed_ms        950 non-null    float64
#  7   wind_direction       951 non-null    object
#  8   temperature_c        956 non-null    float64
#  9   humidity_percent     956 non-null    float64
#  10  precipitation_mm     952 non-null    float64
#  11  traffic_density      957 non-null    object
#  12  industrial_activity  721 non-null    object
#  13  aqi                  947 non-null    float64
# dtypes: float64(11), object(3)
# memory usage: 109.5+ KB

# %%
df.isnull().sum()
# Out:
# pm25_ugm3               48
# pm10_ugm3               39
# no2_ppb                 44
# so2_ppb                 54
# co_ppm                  55
# o3_ppb                  50
# wind_speed_ms           50
# wind_direction          49
# temperature_c           44
# humidity_percent        44
# precipitation_mm        48
# traffic_density         43
# industrial_activity    279
# aqi                     53
# dtype: int64

# %% [markdown]
# **Missing values in Numeric columns**

# %%
df['pm25_ugm3'].isna().sum()
# Out:
# np.int64(48)

# %% [markdown]
# **There are 48 Missing values . Replace using Median**

# %%
df['pm25_ugm3'].fillna(df['pm25_ugm3'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-1534872554.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['pm25_ugm3'].fillna(df['pm25_ugm3'].median(),

# %%
df['pm10_ugm3'].isna().sum()
# Out:
# np.int64(39)

# %% [markdown]
# **39 Missing values . Replace using Median**

# %%
df['pm10_ugm3'].fillna(df['pm10_ugm3'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-2387103378.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['pm10_ugm3'].fillna(df['pm10_ugm3'].median(),

# %%
df['pm10_ugm3'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **NO2**

# %%
df['no2_ppb'].isna().sum()
# Out:
# np.int64(44)

# %% [markdown]
# **44 Values are Missing . use median to Replace**

# %%
df['no2_ppb'].fillna(df['no2_ppb'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-583454805.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['no2_ppb'].fillna(df['no2_ppb'].median(),

# %%
df['no2_ppb'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **SO2**

# %%
df['so2_ppb'].isna().sum()
# Out:
# np.int64(54)

# %% [markdown]
# **54 Values are Missing . Replace using Median**

# %%
df['so2_ppb'].fillna(df['so2_ppb'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-2700421877.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['so2_ppb'].fillna(df['so2_ppb'].median(),

# %%
df['so2_ppb'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **CO**

# %%
df['co_ppm'].isna().sum()
# Out:
# np.int64(55)

# %% [markdown]
# **55 Values are missing . Replace using Median**

# %%
df['co_ppm'].fillna(df['co_ppm'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-3404390820.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['co_ppm'].fillna(df['co_ppm'].median(),

# %%
df['co_ppm'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **O3**

# %%
df['o3_ppb'].isna().sum()
# Out:
# np.int64(50)

# %% [markdown]
# **50 Values Missing . replace using Median**

# %%
df['o3_ppb'].fillna(df['o3_ppb'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-2449235135.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['o3_ppb'].fillna(df['o3_ppb'].median(),

# %%
df['o3_ppb'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Wind Speed**

# %%
df['wind_speed_ms'].isna().sum()
# Out:
# np.int64(50)

# %% [markdown]
# **50 Values Missing . replace using Median**

# %%
df['wind_speed_ms'].fillna(df['wind_speed_ms'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-1844693360.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['wind_speed_ms'].fillna(df['wind_speed_ms'].median(),

# %%
df['wind_speed_ms'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Wind Direction**

# %%
df['wind_direction'].isna().sum()
# Out:
# np.int64(49)

# %% [markdown]
# **49 values are missing**

# %%
df['wind_direction'].fillna(df['wind_direction']=='Not Available',
                  inplace=True)
# Out:
# /tmp/ipython-input-3312444071.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['wind_direction'].fillna(df['wind_direction']=='Not Available',

# %% [markdown]
# **Temperature**

# %%
df['temperature_c'].isna().sum()
# Out:
# np.int64(44)

# %% [markdown]
# **44 values are missing . Replace using Median**

# %%
df['temperature_c'].fillna(df['temperature_c'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-422024535.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['temperature_c'].fillna(df['temperature_c'].median(),

# %%
df['temperature_c'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Humidity**

# %%
df['humidity_percent'].isna().sum()
# Out:
# np.int64(44)

# %% [markdown]
# **44 values are Missing . Replace using Median**

# %%
df['humidity_percent'].fillna(df['humidity_percent'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-3056889664.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['humidity_percent'].fillna(df['humidity_percent'].median(),

# %%
df['humidity_percent'].isna().sum()
# Out:
# np.int64(0)

# %%
df['precipitation_mm'].fillna(df['precipitation_mm'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-443905563.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['precipitation_mm'].fillna(df['precipitation_mm'].median(),

# %%
df['traffic_density'].fillna(df['traffic_density']=='Not Available',
                  inplace=True)
# Out:
# /tmp/ipython-input-3873276457.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['traffic_density'].fillna(df['traffic_density']=='Not Available',

# %%
df['industrial_activity'].fillna(df['industrial_activity']=='Not Available',
                  inplace=True)
# Out:
# /tmp/ipython-input-660911372.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['industrial_activity'].fillna(df['industrial_activity']=='Not Available',

# %%
df['aqi'].fillna(df['aqi'].mean(),
                         inplace=True)
# Out:
# /tmp/ipython-input-2115146935.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['aqi'].fillna(df['aqi'].mean(),

# %%
df = pd.get_dummies(df)

# %%
df
# Out:
#       pm25_ugm3   pm10_ugm3     no2_ppb    so2_ppb    co_ppm      o3_ppb  \
# 0    147.642084  213.479897   75.702572  58.268346  7.509685   24.663439
# 1     60.999935   78.344958    6.781661  49.926301  9.022974  122.185863
# 2    130.243523   76.245903  123.562472  69.652951  3.926962   14.112895
# 3     26.448239  298.713228   75.702572  73.216493  0.145808   34.065477
# 4     77.572169  110.128011   17.982839  92.685193  0.627774  132.934682
# ..          ...         ...         ...        ...       ...         ...
# 995  103.764533  109.976381  106.508625  27.641628  6.681479   30.420299
# 996  131.213849  269.381488    5.458316  52.879834  5.475880   45.024399
# 997   24.893527   13.440303   45.938920  80.747006  9.731895  176.759375
# 998  173.676048  159.918254  115.346588  98.399553  5.995463  140.983134
# 999  188.322866  214.689381   96.043338  35.716778  6.168752  104.248622
#
#      wind_speed_ms  temperature_c  humidity_percent  precipitation_mm  ...  \
# ...

# %%
X = df.drop('aqi', axis=1)

y = df['aqi']

# %%
X
# Out:
#       pm25_ugm3   pm10_ugm3     no2_ppb    so2_ppb    co_ppm      o3_ppb  \
# 0    147.642084  213.479897   75.702572  58.268346  7.509685   24.663439
# 1     60.999935   78.344958    6.781661  49.926301  9.022974  122.185863
# 2    130.243523   76.245903  123.562472  69.652951  3.926962   14.112895
# 3     26.448239  298.713228   75.702572  73.216493  0.145808   34.065477
# 4     77.572169  110.128011   17.982839  92.685193  0.627774  132.934682
# ..          ...         ...         ...        ...       ...         ...
# 995  103.764533  109.976381  106.508625  27.641628  6.681479   30.420299
# 996  131.213849  269.381488    5.458316  52.879834  5.475880   45.024399
# 997   24.893527   13.440303   45.938920  80.747006  9.731895  176.759375
# 998  173.676048  159.918254  115.346588  98.399553  5.995463  140.983134
# 999  188.322866  214.689381   96.043338  35.716778  6.168752  104.248622
#
#      wind_speed_ms  temperature_c  humidity_percent  precipitation_mm  ...  \
# ...

# %%
y
# Out:
# 0      496.000000
# 1      432.000000
# 2      219.000000
# 3      221.000000
# 4      170.000000
#           ...
# 995    253.380148
# 996    253.380148
# 997    263.000000
# 998    154.000000
# 999    273.000000
# Name: aqi, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    train_size=0.8,
                                                    test_size=0.2,
                                                    random_state=42)

# %%
regression_model = LinearRegression()

# %%
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model.predict(X_test)
# Out:
# array([249.48746799, 280.45864285, 266.14720096, 219.00941976,
#        260.73154951, 242.64422242, 235.82814057, 257.27955268,
#        268.08071796, 273.93643964, 276.83281019, 271.5366704 ,
#        252.86193279, 219.93519838, 241.36438681, 245.40032605,
#        271.87509702, 244.64934437, 241.74406605, 254.47841236,
#        252.29936595, 232.76698776, 275.09492771, 232.50372326,
#        257.21733376, 261.96171177, 273.36598181, 287.18085622,
#        301.18278102, 257.9171615 , 257.68724049, 253.5640816 ,
#        260.34682622, 260.99086287, 230.87057355, 246.22932131,
#        255.09147845, 263.53762395, 236.52419334, 235.95976686,
#        217.25132047, 257.58414605, 243.77354453, 269.84965479,
#        254.94060161, 232.83220039, 259.69700362, 275.00677942,
#        259.58517262, 259.88574529, 239.25175586, 246.06777127,
#        266.81882236, 262.00372717, 243.41795875, 256.74431513,
#        244.95331503, 246.34825567, 244.43657527, 282.08003867,
# ...

# %%
y_pred = regression_model.predict(X_test)

# %%
regression_model.coef_
# Out:
# array([-1.12666235e-01, -5.38592721e-02, -5.70633611e-02, -8.04737026e-02,
#         2.24168406e+00, -9.00335209e-02,  1.54618209e+00, -1.42248737e-03,
#        -2.92461432e-01,  3.23697429e-02,  1.42071920e+01, -5.95171473e+00,
#         2.66372102e+00,  7.37932869e+00, -1.56180699e+01, -7.09989428e-01,
#         9.92642255e+00, -4.01344216e+00, -7.88344803e+00,  3.98405218e+00,
#        -9.57914062e+00, -7.96254116e-01, -3.57971463e+00,  9.97105719e+00,
#        -1.28663946e+00,  5.25728251e+00,  1.08151734e+00, -5.05216038e+00])

# %%
regression_model.intercept_
# Out:
# np.float64(287.1716295455201)

# %%
r2_score(y_test, y_pred)
# Out:
# -0.02930567591341582

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 20031.637699185994

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))

print(RMSE)
# Out:
# 141.53316819454722

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.scatter(df['pm25_ugm3'], df['aqi'])
plt.xlabel(" pm25_ugm3")
plt.ylabel("aqi")
plt.title("pm25_ugm3 vs air quality index")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.scatter(df['pm10_ugm3'], df['aqi'])
plt.xlabel(" pm10_ugm3")
plt.ylabel("aqi")
plt.title("pm10_ugm3 vs air quality index")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.scatter(df['no2_ppb'], df['aqi'])
plt.xlabel("no2_ppb")
plt.ylabel("aqi")
plt.title("no2_ppb vs air quality index")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['so2_ppb'], df['aqi'])
plt.xlabel("so2_ppb")
plt.ylabel("aqi")
plt.title("so2_ppb vs air quality index")
plt.show()

# %% [markdown]
# **PREDICTED V/S ACTUAL**

# %%
sns.scatterplot(x=y_test, y=y_pred)
plt.plot(y_test, y_test, color='red')
plt.show()

# %%
plt.figure(figsize=(7,4))
df[['pm25_ugm3','pm10_ugm3','no2_ppb','so2_ppb','co_ppm','o3_ppb','aqi']].boxplot()
plt.title("Boxplot of air pollutants and aqi")
plt.show()
